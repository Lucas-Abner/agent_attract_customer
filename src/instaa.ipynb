# %%
import ensta
import time
import os
import random
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 import ensta
#       2 import time
#       3 import os
#
# File c:\Users\asus\Documents\IA\agent_attract_customer\.venv\Lib\site-packages\ensta\__init__.py:2
#       1 from ensta.Guest import Guest
# ----> 2 from ensta.WebSession import WebSession
#       3 from ensta.Web import Web
#       4 from ensta.lib import Exceptions
#
# File c:\Users\asus\Documents\IA\agent_attract_customer\.venv\Lib\site-packages\ensta\WebSession.py:8
#       6 import string
#       7 import requests
# ----> 8 import moviepy.editor
#       9 from uuid import uuid4
#      10 from .Guest import Guest
#
# File c:\Users\asus\Documents\IA\agent_attract_customer\.venv\Lib\site-packages\moviepy\editor.py:41
#      39 from .video.VideoClip import VideoClip, ImageClip, ColorClip, TextClip
# ...

# %%
cl = Mobile()

USERNAME = os.getenv("LOGIN_USERNAME", "llucasabner")
PASSWORD = os.getenv("LOGIN_PASSWORD", "lucascaixeta1")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 cl = Mobile()
#       3 USERNAME = os.getenv("LOGIN_USERNAME", "llucasabner")
#       4 PASSWORD = os.getenv("LOGIN_PASSWORD", "lucascaixeta1")
#
# NameError: name 'Mobile' is not defined
